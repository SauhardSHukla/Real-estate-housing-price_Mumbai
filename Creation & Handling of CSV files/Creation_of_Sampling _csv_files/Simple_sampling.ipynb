# %% [markdown]
# ### Creation of the Simple sample of the dataframe

# %%
#Import the lib
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ***Step 1: Load the DataSet***

# %%
df = pd.read_csv('C:/Users/5530/OneDrive/Desktop/Real_State_Housing_Mumbai/Creation & Handling of CSV files/CSV_Files/Mumbai_Housing_Real_Estate.csv')

# Show case the Values 
df.head()
# Out:
#    property_id  locality property_type  bhk  size_sqft  price_lakhs  \
# 0            1     Malad        Studio    1    1292.29       136.95
# 1            2     Powai     Apartment    2     894.23       112.35
# 2            3  Goregaon     Apartment    1     915.87       190.00
# 3            4  Borivali        Studio    3     889.52       126.44
# 4            5     Malad     Apartment    2    1019.09       260.05
#
#    rent_monthly   availability  possession_year furnished_status  \
# 0       55665.0  Ready to move             2025      Unfurnished
# 1       41791.0  Ready to move             2025        Furnished
# 2       29550.0  Ready to move             2025   Semi-Furnished
# 3       50435.0  Ready to move             2025        Furnished
# 4       40941.0  Ready to move             2025      Unfurnished
#
#              posted_on
# 0  2024-04-23 00:00:00
# 1  2024-04-08 00:00:00
# 2  2024-06-26 00:00:00
# 3  2024-07-07 00:00:00
# 4  2024-09-26 00:00:00

# %% [markdown]
# ***Step 2: Simple Random Sampling***

# %%
sample_size = int(0.1 * len(df))
simple_random_sample = df.sample(n= sample_size,random_state=42)

#Showcase the first 5 values
simple_random_sample.head(5)
# Out:
#       property_id locality property_type  bhk  size_sqft  price_lakhs  \
# 6252         6253    Dadar     Apartment    2     903.05       238.45
# 4684         4685   Bandra     Apartment    3     926.21       184.56
# 1731         1732    Malad     Apartment    2     903.37       200.74
# 4742         4743    Powai     Apartment    4     901.15       185.17
# 4521         4522    Dadar     Apartment    1     879.23       144.83
#
#       rent_monthly   availability  possession_year furnished_status  \
# 6252       39408.0  Ready to move             2025      Unfurnished
# 4684       16770.0  Ready to move             2026        Furnished
# 1731       30879.0  Ready to move             2024   Semi-Furnished
# 4742       60399.0  Ready to move             2024   Semi-Furnished
# 4521       51897.0  Ready to move             2024   Semi-Furnished
#
#                 posted_on
# 6252  2024-05-13 00:00:00
# 4684  2024-10-23 00:00:00
# 1731  2024-07-06 00:00:00
# ...

# %%
# Save the sampled dataset to CSV

simple_random_sample.to_csv("C:/Users/5530/OneDrive/Desktop/Real_State_Housing_Mumbai/Creation & Handling of CSV files/CSV_Files/simple_sampling.csv", index=False)
print("✅ Sample saved to data/real_estate_sample.csv")
# C:\Users\5530\OneDrive\Desktop\Real_State_Housing_Mumbai\Creation & Handling of CSV files\CSV_Files
# Out:
# ✅ Sample saved to data/real_estate_sample.csv
